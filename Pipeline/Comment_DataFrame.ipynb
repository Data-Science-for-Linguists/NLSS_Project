# %% [markdown]
# # Overview
#
# This notebook shows how a dataframe containing usernames and comments can be created from the JSON files.

# %%
# Every returned Out[] is displayed, not just the last one. 
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import pandas as pd

# %%
rechat_df = pd.read_json('rechat-169562281.json')
rechat_df.head()
# Out:
#                                     _id  \
# 0                            v169562281
# 1  06cb56dc-7b95-4505-b1fd-f6d59e77266f
# 2  0bf17300-7d2c-4e98-bdf6-3336ee36703a
# 3  1545a1af-eca2-4197-a72f-6feb4ba8117f
# 4  1e1d43c7-e8e5-4033-87d1-92c46e15e934
#
#                                               _links  \
# 0  {'self': 'https://api.twitch.tv/kraken/videos/...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                 animated_preview_url  broadcast_id  \
# 0  https://vod-storyboards.twitch.tv/a7bf751d5cbf...  2.609443e+10
# 1                                                NaN           NaN
# 2                                                NaN           NaN
# 3                                                NaN           NaN
# 4                                                NaN           NaN
#
#   broadcast_type                                            channel  \
# 0      highlight  {'name': 'northernlion', 'display_name': 'Nort...
# 1            NaN                                                NaN
# 2            NaN                                                NaN
# 3            NaN                                                NaN
# 4            NaN                                                NaN
#
#    channel_id                                          commenter   content_id  \
# 0         NaN                                                NaN          NaN
# 1  14371185.0  {'display_name': 'Moobot', '_id': '1564983', '...  169562281.0
# 2  14371185.0  {'display_name': 'emperorvespasian', '_id': '1...  169562281.0
# 3  14371185.0  {'display_name': 'KhanWight', '_id': '43782340...  169562281.0
# 4  14371185.0  {'display_name': 'Aheron211', '_id': '54256158...  169562281.0
#
#    content_offset_seconds   ...    \
# 0                     NaN   ...
# 1                   0.264   ...
# 2                   0.392   ...
# 3                   0.485   ...
# 4                   0.504   ...
#
#                                          resolutions source      state  \
# 0  {'160p30': '284x160', '360p30': '640x360', '48...    NaN        NaN
# 1                                                NaN   chat  published
# 2                                                NaN   chat  published
# 3                                                NaN   chat  published
# 4                                                NaN   chat  published
#
#      status tag_list                                         thumbnails  \
# 0  recorded           [{'type': 'generated', 'url': 'https://static-...
# 1       NaN      NaN                                                NaN
# 2       NaN      NaN                                                NaN
# 3       NaN      NaN                                                NaN
# 4       NaN      NaN                                                NaN
#
#                title              updated_at  \
# 0  NLSS [08/24/2017]                     NaT
# 1                NaN 2017-08-24 21:04:39.764
# 2                NaN 2017-08-24 21:04:39.892
# 3                NaN 2017-08-24 21:04:39.985
# 4                NaN 2017-08-24 21:04:40.004
#
#                                       url   views
# 0  https://www.twitch.tv/videos/169562281  4063.0
# 1                                     NaN     NaN
# 2                                     NaN     NaN
# 3                                     NaN     NaN
# 4                                     NaN     NaN
#
# [5 rows x 33 columns]

# %% [markdown]
# It looks like our first row is video info. This might be important to know when trying to get messages.

# %%
#list of column names.
list(rechat_df)
# Out:
# ['_id',
#  '_links',
#  'animated_preview_url',
#  'broadcast_id',
#  'broadcast_type',
#  'channel',
#  'channel_id',
#  'commenter',
#  'content_id',
#  'content_offset_seconds',
#  'content_type',
#  'created_at',
#  'description',
#  'description_html',
#  'fps',
#  'game',
#  'language',
#  'length',
#  'message',
#  'more_replies',
#  'preview',
#  'published_at',
#  'recorded_at',
#  'resolutions',
#  'source',
#  'state',
#  'status',
#  'tag_list',
#  'thumbnails',
#  'title',
#  'updated_at',
#  'url',
#  'views']

# %% [markdown]
# Message looks like it is the comment.

# %%
#When running, replace 1 with row number
message_df = rechat_df[['message']]
message_df.head()
#This format will print out the comment from a row in the df, where 1 is the row of the comment, and cannot be 0
print(message_df.loc[1][0]['body'])
# Out:
#                                              message
# 0                                                NaN
# 1  {'body': 'Thank you for subbing, IHaveNoPokeCl...
# 2  {'body': 'VERY LARGE CONE', 'fragments': [{'te...
# 3  {'body': 'Kreygasm CLIMAX Kreygasm CLIMAX Krey...
# 4  {'body': 'VLC', 'fragments': [{'text': 'VLC'}]...
# Thank you for subbing, IHaveNoPokeClue! :D :D

# %%
commenter_df = rechat_df[['commenter']]
commenter_df.head()
print(commenter_df.loc[1][0]['display_name'])
# Out:
#                                            commenter
# 0                                                NaN
# 1  {'display_name': 'Moobot', '_id': '1564983', '...
# 2  {'display_name': 'emperorvespasian', '_id': '1...
# 3  {'display_name': 'KhanWight', '_id': '43782340...
# 4  {'display_name': 'Aheron211', '_id': '54256158...
# Moobot

# %%
len(commenter_df)
len(message_df)
# Out:
# 21832
# 21832

# %%
for x in message_df.index[:100]: #For every number in index
    if x != 0: #Skip first index
        print(commenter_df.loc[x][0]['display_name'], ':', message_df.loc[x][0]['body'])
# Out:
# Moobot : Thank you for subbing, IHaveNoPokeClue! :D :D
# emperorvespasian : VERY LARGE CONE
# KhanWight : Kreygasm CLIMAX Kreygasm CLIMAX Kreygasm
# Aheron211 : VLC
# Nightbot : Necropara -> Squeal piggy! Squeal [stop spamming caps] [warning]
# T3chedOut : THE CONE
# Newspire : DISRESPECT
# Zeldawiz : LUL
# Overlord_king : VLC
# Blargheon : VLC
# its_opaque_not_clear : !docket
# TheobromaCacao : lionElmoFace
# Nightbot : TODAY'S DOCKET: Passpartout > Party Panic > Pinturillo (🅿 day)
# EnviChan : there is that disrespect
# Kachopper90 : LUL
# Tom1slav : VLC PLAYER
# anonymous_nobody_ : VoteNay
# jarjarblinksxddddddddddr : VL🅿
# BME02 : VLC
# getdustedyun : V L C
# HappyModule : VLC
# Navy_Raccoon : VLC
# Flowz0r91 : VLC
# tomojo_jojo : PARTY PANIC
# kulapik : VLC
# Moobot : Welcome Yamorama! :D :D :D
# MoximusGames : REPRESS THIS
# Tydus_10 : VLC
# KhanWight : CLIMAX Kreygasm CLIMAX Kreygasm
# oxmn : VLC
# tidge_ : v l c
# DoctorDisturbed : VLC
# hsbn7 : VLC
# Qaqawsrr1 : !docket
# tomojo_jojo : l a its go
# TrFessler : DISRESPECT
# Nightbot : TODAY'S DOCKET: Passpartout > Party Panic > Pinturillo (🅿 day)
# ShoresofSerenity : LUL
# anonymous_nobody_ : V L C
# Moobot : Thanks for subbing, bonglord69! <3 <3 <3
# grumpymatt : VLC
# straightouttagorton : START THE SHIT AGAIN
# luigimasta777 : V L C
# LPthorin : LUL
# Deus_Mortuus : AN ORANGE CONE
# evol66 : lionElmoFace
# Iyiyiy9 : stop this disrespect
# Berwhale : VLC
# Mealkey : !docket
# Nightbot : TODAY'S DOCKET: Passpartout > Party Panic > Pinturillo (🅿 day)
# Fronku : lionDemon1 lionDemon2
# IsuleOTI : LETS GOOOOOOOOOOOOO lionDemon1 lionDemon2
# TheTwistedTruth : NL play the Yu Gi Oh intro for once you beta male
# norman6969 : VLC
# Noremac__ : It was too late lionFeels
# GigaVamp : Squid4 Squid3 Squid1
# Zeemod155 : Cur Tailed
# Negative_Space : That was the intro they used back when I first started watching way back in 13' you young whippersnappers
# jarjarblinksxddddddddddr : 🅿orthern 🅿ion
# salad_snack_ : fucking cobalt...
# Necropara : Hey bald jerk, you suck. Lick on my pee-pee.
# Berwhale : lionNick
# luigimasta777 : curtail lul
# Eluc : 🅿 day, aka cobalt day, aka rob finally got the game he wanted on the docket day
# StygianSeraphim : :p: L S S
# MalignantUpper : 🅿
# mrMoonbirdMonster : !discord JOIN
# Nightbot : NL fan discord: https://discord.gg/bu8fxnQ
# Big_Bossuru : fucking cobalt day, see you guys
# GuntherDaPenguin : RETIRE THAT INTRODUCTION
# BrowncoatMoose : Squid1 Squid2 Squid3 Squid4
# RaidanRam : umm actually strimmer it's 7:05 am
# Roeming : P
# zesty69pepper : VeryLargeCone
# tomojo_jojo : 🅿 day
# ArrestedHouse : BroBalt
# ShoresofSerenity : BroBalt
# Navy_Raccoon : BroBalt
# KhanWight : COBALT <3
# oxmn : coblat
# CallMeSDR : NL is too lazy to download new intros
# cmeats : oh no
# UW_Rabbit : dafuq
# 4storycheese : Low t
# Tydus_10 : lionRobert
# Eluc : BroBalt
# gibbozzz : MULTI STREAm
# the_breaded_one : oh no
# ArrestedHouse : lionRobert
# Noremac__ : AKA No Clothes Family Day
# ShoresofSerenity : RaccAttack
# katanalauncher : Colbalt haters DansGame
# grayyyylmao : BroBal
# Fronku : lionDemon3 lionDemon4
# Navy_Raccoon : lionRobert
# Overlord_king : LUL
# FangSamurai85 : what is the VLC meme?
# THORNFORG3 : R O 🅿
# anonymous_nobody_ : BroBalt

# %% [markdown]
# Lets make a DataFrame of comments

# %%
comments = []
for x in message_df.index: #For every number in index
    if x != 0: #Skip first index
        comments.append([commenter_df.loc[x][0]['display_name'], message_df.loc[x][0]['body']])
        
comment_df = pd.DataFrame(comments)
comment_df.head()
# Out:
#                   0                                                  1
# 0            Moobot      Thank you for subbing, IHaveNoPokeClue! :D :D
# 1  emperorvespasian                                    VERY LARGE CONE
# 2         KhanWight           Kreygasm CLIMAX Kreygasm CLIMAX Kreygasm
# 3         Aheron211                                                VLC
# 4          Nightbot  Necropara -> Squeal piggy! Squeal [stop spammi...

# %%
comment_df.columns = ['User', 'Comment']
comment_df[:20]
# Out:
#                         User  \
# 0                     Moobot
# 1           emperorvespasian
# 2                  KhanWight
# 3                  Aheron211
# 4                   Nightbot
# 5                  T3chedOut
# 6                   Newspire
# 7                   Zeldawiz
# 8              Overlord_king
# 9                  Blargheon
# 10      its_opaque_not_clear
# 11            TheobromaCacao
# 12                  Nightbot
# 13                  EnviChan
# 14               Kachopper90
# 15                  Tom1slav
# 16         anonymous_nobody_
# 17  jarjarblinksxddddddddddr
# 18                     BME02
# 19              getdustedyun
#
#                                               Comment
# 0       Thank you for subbing, IHaveNoPokeClue! :D :D
# 1                                     VERY LARGE CONE
# 2            Kreygasm CLIMAX Kreygasm CLIMAX Kreygasm
# 3                                                 VLC
# 4   Necropara -> Squeal piggy! Squeal [stop spammi...
# 5                                            THE CONE
# 6                                          DISRESPECT
# 7                                                 LUL
# 8                                                 VLC
# 9                                                 VLC
# 10                                            !docket
# 11                                       lionElmoFace
# 12  TODAY'S DOCKET: Passpartout > Party Panic > Pi...
# 13                           there is that disrespect
# 14                                                LUL
# 15                                         VLC PLAYER
# 16                                            VoteNay
# 17                                                VL🅿
# 18                                                VLC
# 19                                              V L C
